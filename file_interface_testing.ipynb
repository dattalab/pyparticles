# %%
import h5py
import numpy as np
import os
from matplotlib import pyplot as plt
na = np.newaxis

from renderer.renderer import MouseScene
from renderer.load_data import load_new_behavior_data

import experiments
from experiments import Experiment
import pose_models
import particle_filter
import predictive_models as pm
import predictive_distributions as pd
from util.text import progprint_xrange

root = os.path.dirname(os.path.abspath(os.getcwd()))

# %%
msNumRows, msNumCols = 32,32
ms = None
def _build_mousescene(scenefilepath):
    global ms
    if ms is None:
        ms = MouseScene(scenefilepath, mouse_width=80, mouse_height=80, \
                        scale_width = 18.0, scale_height = 200.0,
                        scale_length = 18.0, \
                        numCols=msNumCols, numRows=msNumRows, useFramebuffer=True,showTiming=False)
        ms.gl_init()
    return ms

def _load_data(datapath,frame_range):
    xy = load_new_behavior_data(datapath, frame_range[1] + 1, 'centroid')[frame_range[0]:]
    theta = load_new_behavior_data(datapath, frame_range[1] + 1, 'angle')[frame_range[0]:]
    xytheta = np.concatenate((xy, theta[:, na]), axis=1)
    images = load_new_behavior_data(datapath, frame_range[1] + 1, 'images').astype('float32')[frame_range[0]:]
    images_rot = np.array([image.T[::-1, :] for image in images])
    return images_rot, xytheta

# %%
class RandomWalkFixedNoiseFrozenTrack_AW_5Joints_simplified(Experiment):
    # should look a lot like RandomWalkFixedNoise
    def run(self,frame_range):
        datapath = os.path.join(root, "data/extracted_data/2019-03-20_17-31-38_saline_example_0_000070_results_00.h5")

        num_particles_firststep = 1024*10
        num_particles = 1024*10
        cutoff = 1024*10

        lag = 15

        pose_model = pose_models.PoseModel_5Joint_origweights_AW()
        
        variances = {
            'x':             {'init':3.0,  'subsq':1.5},
            'y':             {'init':3.0,  'subsq':1.5},
            'theta_yaw':     {'init':7.0,  'subsq':3.0},
            'z':             {'init':3.0,  'subsq':0.25},
            'theta_roll':    {'init':0.01, 'subsq':0.01},
            's_w':           {'init':2.0,  'subsq':1e-6},
            's_l':           {'init':2.0,  'subsq':1e-6},
            's_h':           {'init':1.0,  'subsq':1e-6}
        }
        particle_fields = pose_model.ParticlePose._fields
        joint_names = [j for j in particle_fields if 'psi_' in j]
        [variances.update({j:{'init':20.0, 'subsq':5.0}}) for j in joint_names]

        randomwalk_noisechol = np.diag([variances[p]['init'] for p in particle_fields])
        subsequent_randomwalk_noisechol = np.diag([variances[p]['subsq'] for p in particle_fields])

        # TODO check z size
        # TODO try cutting scale, fit on first 10 or so

        _build_mousescene(pose_model.scenefilepath)
        images, xytheta = _load_data(datapath,frame_range)
        
        pose_model.default_renderer_pose = \
            pose_model.default_renderer_pose._replace(theta_yaw=xytheta[0,2],x=xytheta[0,0],y=xytheta[0,1])
        pose_model.default_particle_pose = \
            pose_model.default_particle_pose._replace(theta_yaw=xytheta[0,2],x=xytheta[0,0],y=xytheta[0,1])

        def log_likelihood(stepnum,im,poses):
            return ms.get_likelihood(im,particle_data=pose_model.expand_poses(poses),
                x=xytheta[stepnum,0],y=xytheta[stepnum,1],theta=xytheta[stepnum,2])/2000.

        pf = particle_filter.ParticleFilter(
                pose_model.particle_pose_tuple_len,
                cutoff,
                log_likelihood,
                [particle_filter.AR(
                    num_ar_lags=1,
                    previous_outputs=(pose_model.default_particle_pose,),
                    baseclass=lambda: pm.RandomWalk(noiseclass=lambda: pd.FixedNoise(randomwalk_noisechol))
                    ) for itr in range(num_particles_firststep)])

        pf.step(images[0])
        pf.change_numparticles(num_particles)
        randomwalk_noisechol[:] = subsequent_randomwalk_noisechol[:]

        for i in progprint_xrange(1,lag):
            pf.step(images[i])
        self.save_progress(pf,pose_model,datapath,frame_range,means=[])

        # now step with freezing means
        means = []
        for i in progprint_xrange(lag,images.shape[0],perline=10):
            means.append(np.sum(pf.weights_norm[:,na] * np.array([p.track[i-lag] for p in pf.particles]),axis=0))
            print('\nsaved a mean for index %d with %d unique particles!\n' % \
                    (i-lag,len(np.unique([p.track[i-15][0] for p in pf.particles]))))

            pf.step(images[i])

            if (i % 5) == 0:
                self.save_progress(pf,pose_model,datapath,frame_range,means=means)

        self.save_progress(pf,pose_model,datapath,frame_range,means=means)

# %%
# ==================================================
#                     SERIAL
# ==================================================
# This is how we do things serially

RandomWalkFixedNoiseFrozenTrack_AW_5Joints_simplified((100,200)).run((100,200))
# Out:
# results directory: results/8218897506270013465.100.200
# 169.34881835795883
# 1776
# 1991.95768844505
# 4443
# .5641.54581932346
# 6199
# .7926.947096973737
# 7993
# .8503.386966865346
# 8393
# .8440.144780359376
# 8336
# .8334.700937448244
# 8269
# .8425.028192425756
# 8342
# .8417.867108933408
# 8281
# .8167.201887606497
# 8147
# .8092.248678984923
# 8049
# .8317.604246836408
# 8174
# .8191.356847945012
# 8065
# .8401.68791893004
# 8199
# .8320.87132170167
# 8173
# .
#    1.73sec avg,   24.23sec total
#
#
# saved a mean for index 0 with 1 unique particles!
#
# 8705.024344430696
# 8450
# .
# saved a mean for index 1 with 255 unique particles!
#
# 8676.033527570204
# 8419
# .
# saved a mean for index 2 with 461 unique particles!
#
# 8978.744195479627
# 8664
# .
# saved a mean for index 3 with 511 unique particles!
#
# 8842.6813657779
# 8586
# .
# saved a mean for index 4 with 516 unique particles!
#
# 9000.862285425857
# 8655
# .
# saved a mean for index 5 with 537 unique particles!
#
# 9239.540270318616
# 8898
# .
# saved a mean for index 6 with 560 unique particles!
#
# 9138.165269603785
# 8777
# .
# saved a mean for index 7 with 617 unique particles!
#
# 9268.1659392536
# 8915
# .
# saved a mean for index 8 with 655 unique particles!
#
# 9224.356190101562
# 8820
# .
# saved a mean for index 9 with 726 unique particles!
#
# 8914.86839407875
# 8596
# .  [ 10/86,    1.63sec avg,  124.13sec ETA ]
#
# saved a mean for index 10 with 828 unique particles!
#
# 8969.466882119916
# 8628
# .
# saved a mean for index 11 with 910 unique particles!
#
# 9175.056188257528
# 8833
# .
# saved a mean for index 12 with 992 unique particles!
#
# 9043.350871176792
# 8720
# .
# saved a mean for index 13 with 1085 unique particles!
#
# 9271.548626374588
# 8892
# .
# saved a mean for index 14 with 1166 unique particles!
#
# 9218.479321889072
# 8891
# .
# saved a mean for index 15 with 1253 unique particles!
#
# 9126.126177240734
# 8786
# .
# saved a mean for index 16 with 1334 unique particles!
#
# 9382.313517903596
# 8997
# .
# saved a mean for index 17 with 1441 unique particles!
#
# 9411.584720609197
# 9010
# .
# saved a mean for index 18 with 1507 unique particles!
#
# 9478.394616715646
# 9065
# .
# saved a mean for index 19 with 1586 unique particles!
#
# 9428.82769085586
# 9065
# .  [ 20/86,    1.69sec avg,  111.76sec ETA ]
#
# saved a mean for index 20 with 1645 unique particles!
#
# 9460.183238165144
# 9043
# .
# saved a mean for index 21 with 1656 unique particles!
#
# 9382.0231336574
# 9000
# .
# saved a mean for index 22 with 1668 unique particles!
#
# 9201.511072301173
# 8860
# .
# saved a mean for index 23 with 1656 unique particles!
#
# 9088.131186672932
# 8767
# .
# saved a mean for index 24 with 1661 unique particles!
#
# 9305.486937846545
# 8921
# .
# saved a mean for index 25 with 1730 unique particles!
#
# 9271.28412467842
# 8856
# .
# saved a mean for index 26 with 1760 unique particles!
#
# 9298.660441288584
# 8933
# .
# saved a mean for index 27 with 1768 unique particles!
#
# 9194.818949328552
# 8827
# .
# saved a mean for index 28 with 1731 unique particles!
#
# 8839.501465925074
# 8582
# .
# saved a mean for index 29 with 1658 unique particles!
#
# 8840.182109797082
# 8543
# .  [ 30/86,    1.74sec avg,   97.50sec ETA ]
#
# saved a mean for index 30 with 1564 unique particles!
#
# 8800.134535042715
# 8518
# .
# saved a mean for index 31 with 1455 unique particles!
#
# 9123.586951441006
# 8776
# .
# saved a mean for index 32 with 1363 unique particles!
#
# 8859.958226386389
# 8537
# .
# saved a mean for index 33 with 1261 unique particles!
#
# 9014.285669541061
# 8671
# .
# saved a mean for index 34 with 1173 unique particles!
#
# 8923.31841588117
# 8589
# .
# saved a mean for index 35 with 1100 unique particles!
#
# 9037.63088737645
# 8677
# .
# saved a mean for index 36 with 1053 unique particles!
#
# 9308.1149823173
# 8887
# .
# saved a mean for index 37 with 1046 unique particles!
#
# 9404.077146999283
# 9032
# .
# saved a mean for index 38 with 1046 unique particles!
#
# 9382.736207907159
# 9003
# .
# saved a mean for index 39 with 1077 unique particles!
#
# 9428.520780503646
# 9059
# .  [ 40/86,    1.76sec avg,   80.74sec ETA ]
#
# saved a mean for index 40 with 1121 unique particles!
#
# 9572.721662039681
# 9172
# .
# saved a mean for index 41 with 1179 unique particles!
#
# 9551.093345229261
# 9114
# .
# saved a mean for index 42 with 1251 unique particles!
#
# 9551.24207485268
# 9141
# .
# saved a mean for index 43 with 1333 unique particles!
#
# 9634.253295514489
# 9221
# .
# saved a mean for index 44 with 1447 unique particles!
#
# 9523.70388992262
# 9095
# .
# saved a mean for index 45 with 1574 unique particles!
#
# 9577.414294799551
# 9180
# .
# saved a mean for index 46 with 1691 unique particles!
#
# 9570.547876913492
# 9127
# .
# saved a mean for index 47 with 1768 unique particles!
#
# 9563.514257613317
# 9148
# .
# saved a mean for index 48 with 1880 unique particles!
#
# 9549.41382543692
# 9140
# .
# saved a mean for index 49 with 1974 unique particles!
#
# 9492.769115443629
# 9105
# .  [ 50/86,    1.79sec avg,   64.32sec ETA ]
#
# saved a mean for index 50 with 2062 unique particles!
#
# 9512.316942459433
# 9093
# .
# saved a mean for index 51 with 2121 unique particles!
#
# 9550.415204574887
# 9163
# .
# saved a mean for index 52 with 2112 unique particles!
#
# 9455.296794290238
# 9060
# .
# saved a mean for index 53 with 2077 unique particles!
#
# 8986.421723612022
# 8643
# .
# saved a mean for index 54 with 2068 unique particles!
#
# 9166.688937466986
# 8815
# .
# saved a mean for index 55 with 2005 unique particles!
#
# 8738.005817769632
# 8480
# .
# saved a mean for index 56 with 1882 unique particles!
#
# 7743.086037161656
# 7792
# .
# saved a mean for index 57 with 1714 unique particles!
#
# 8013.909507778938
# 7977
# .
# saved a mean for index 58 with 1509 unique particles!
#
# 8027.1542099572225
# 7982
# .
# saved a mean for index 59 with 1295 unique particles!
#
# 7897.692904610192
# 7888
# .  [ 60/86,    1.82sec avg,   47.41sec ETA ]
#
# saved a mean for index 60 with 1094 unique particles!
#
# 7114.336448642915
# 7464
# .
# saved a mean for index 61 with 890 unique particles!
#
# 7912.84233525285
# 7859
# .
# saved a mean for index 62 with 724 unique particles!
#
# 8460.414893632043
# 8310
# .
# saved a mean for index 63 with 608 unique particles!
#
# 8954.235369138301
# 8633
# .
# saved a mean for index 64 with 540 unique particles!
#
# 9365.32657490691
# 8975
# .
# saved a mean for index 65 with 513 unique particles!
#
# 9483.929076564946
# 9105
# .
# saved a mean for index 66 with 503 unique particles!
#
# 9599.777820212146
# 9183
# .
# saved a mean for index 67 with 485 unique particles!
#
# 9612.636856155304
# 9174
# .
# saved a mean for index 68 with 494 unique particles!
#
# 9624.430713126405
# 9205
# .
# saved a mean for index 69 with 524 unique particles!
#
# 9733.443524421327
# 9324
# .  [ 70/86,    1.81sec avg,   28.99sec ETA ]
#
# saved a mean for index 70 with 562 unique particles!
#
# 9703.343498232645
# 9297
# .
# saved a mean for index 71 with 631 unique particles!
#
# 9701.470888039124
# 9304
# .
# saved a mean for index 72 with 780 unique particles!
#
# 9651.099794340567
# 9272
# .
# saved a mean for index 73 with 946 unique particles!
#
# 9586.45264766038
# 9178
# .
# saved a mean for index 74 with 1129 unique particles!
#
# 9491.268669005942
# 9094
# .
# saved a mean for index 75 with 1355 unique particles!
#
# 9469.414634775565
# 9054
# .
# saved a mean for index 76 with 1724 unique particles!
#
# 9238.182980813232
# 8874
# .
# saved a mean for index 77 with 1971 unique particles!
#
# 8886.311929399097
# 8591
# .
# saved a mean for index 78 with 2045 unique particles!
#
# 9264.962599413366
# 8910
# .
# saved a mean for index 79 with 2059 unique particles!
#
# 9013.241276430133
# 8683
# .  [ 80/86,    1.82sec avg,   10.92sec ETA ]
#
# saved a mean for index 80 with 1978 unique particles!
#
# 9317.633754843948
# 8946
# .
# saved a mean for index 81 with 1910 unique particles!
#
# 9097.767746342432
# 8781
# .
# saved a mean for index 82 with 1816 unique particles!
#
# 9153.760616203861
# 8838
# .
# saved a mean for index 83 with 1706 unique particles!
#
# 9219.918656228705
# 8922
# .
# saved a mean for index 84 with 1590 unique particles!
#
# 8919.947244902594
# 8689
# .
# saved a mean for index 85 with 1500 unique particles!
#
# 8902.709211077125
# 8704
# .
#    1.85sec avg,  158.99sec total
#
# 141.75064844262945
# 1655
# 2128.8148996700997
# 4493
# .6209.020036591249
# 6402
# .8730.468589868553
# 8584
# .9236.707191862526
# 8908
# .9138.121945060571
# 8826
# .9002.988838986894
# 8733
# .9010.938637680518
# 8745
# .8935.177336761872
# 8649
# .8605.925297986782
# 8433
# .8451.094694351692
# 8295
# .8612.924073044474
# 8416
# .8442.60646461041
# 8301
# .8533.149576353479
# 8388
# .8414.381819524739
# 8297
# .
#    2.06sec avg,   28.88sec total
#
#
# saved a mean for index 0 with 1 unique particles!
#
# 8706.2504478498
# 8475
# .
# saved a mean for index 1 with 390 unique particles!
#
# 8685.423915387077
# 8453
# .
# saved a mean for index 2 with 743 unique particles!
#
# 8942.536283413334
# 8657
# .
# saved a mean for index 3 with 728 unique particles!
#
# 8834.61937613716
# 8557
# .
# saved a mean for index 4 with 696 unique particles!
#
# 8951.206497726893
# 8644
# .
# saved a mean for index 5 with 665 unique particles!
#
# 9135.282522129703
# 8813
# .
# saved a mean for index 6 with 646 unique particles!
#
# 9065.512862188927
# 8744
# .
# saved a mean for index 7 with 624 unique particles!
#
# 9136.134119941602
# 8795
# .
# saved a mean for index 8 with 622 unique particles!
#
# 9194.923693755894
# 8846
# .
# saved a mean for index 9 with 647 unique particles!
#
# 8909.37601089691
# 8610
# .  [ 10/86,    2.39sec avg,  181.99sec ETA ]
#
# saved a mean for index 10 with 690 unique particles!
#
# 8950.91642218881
# 8677
# .
# saved a mean for index 11 with 743 unique particles!
#
# 9102.230968489353
# 8786
# .
# saved a mean for index 12 with 781 unique particles!
#
# 8996.696595978807
# 8721
# .
# saved a mean for index 13 with 832 unique particles!
#
# 9191.31098314514
# 8870
# .
# saved a mean for index 14 with 915 unique particles!
#
# 9166.437496931325
# 8794
# .
# saved a mean for index 15 with 958 unique particles!
#
# 9102.631026872026
# 8827
# .
# saved a mean for index 16 with 1019 unique particles!
#
# 9311.701263160041
# 8961
# .
# saved a mean for index 17 with 1087 unique particles!
#
# 9363.820649673808
# 9020
# .
# saved a mean for index 18 with 1137 unique particles!
#
# 9414.598942731278
# 9009
# .
# saved a mean for index 19 with 1190 unique particles!
#
# 9387.409026919451
# 9033
# .  [ 20/86,    2.14sec avg,  141.31sec ETA ]
#
# saved a mean for index 20 with 1271 unique particles!
#
# 9434.468392881383
# 9041
# .
# saved a mean for index 21 with 1304 unique particles!
#
# 9351.52264275368
# 9003
# .
# saved a mean for index 22 with 1331 unique particles!
#
# 9199.242451988473
# 8821
# .
# saved a mean for index 23 with 1351 unique particles!
#
# 9124.181701094805
# 8804
# .
# saved a mean for index 24 with 1390 unique particles!
#
# 9327.267650881457
# 8945
# .
# saved a mean for index 25 with 1444 unique particles!
#
# 9292.84356645673
# 8950
# .
# saved a mean for index 26 with 1501 unique particles!
#
# 9273.896977387894
# 8907
# .
# saved a mean for index 27 with 1542 unique particles!
#
# 9201.471613809832
# 8810
# .
# saved a mean for index 28 with 1519 unique particles!
#
# 8909.217075271676
# 8643
# .
# saved a mean for index 29 with 1485 unique particles!
#
# 8901.414550641619
# 8625
# .  [ 30/86,    2.03sec avg,  113.73sec ETA ]
#
# saved a mean for index 30 with 1411 unique particles!
#
# 8886.772686214621
# 8559
# .
# saved a mean for index 31 with 1355 unique particles!
#
# 9133.254896277884
# 8777
# .
# saved a mean for index 32 with 1301 unique particles!
#
# 8965.081359594165
# 8651
# .
# saved a mean for index 33 with 1235 unique particles!
#
# 9022.246495964117
# 8689
# .
# saved a mean for index 34 with 1161 unique particles!
#
# 8932.70352192767
# 8624
# .
# saved a mean for index 35 with 1093 unique particles!
#
# 9015.598250250809
# 8688
# .
# saved a mean for index 36 with 1073 unique particles!
#
# 9288.724718747022
# 8909
# .
# saved a mean for index 37 with 1064 unique particles!
#
# 9363.35628879685
# 8977
# .
# saved a mean for index 38 with 1081 unique particles!
#
# 9392.763439942197
# 9017
# .
# saved a mean for index 39 with 1108 unique particles!
#
# 9350.529646930916
# 8998
# .  [ 40/86,    1.95sec avg,   89.71sec ETA ]
#
# saved a mean for index 40 with 1112 unique particles!
#
# 9501.093600594824
# 9124
# .
# saved a mean for index 41 with 1168 unique particles!
#
# 9528.436895269713
# 9098
# .
# saved a mean for index 42 with 1234 unique particles!
#
# 9528.98437385566
# 9099
# .
# saved a mean for index 43 with 1320 unique particles!
#
# 9576.241144451107
# 9202
# .
# saved a mean for index 44 with 1435 unique particles!
#
# 9449.705968213952
# 9075
# .
# saved a mean for index 45 with 1544 unique particles!
#
# 9484.050111174472
# 9074
# .
# saved a mean for index 46 with 1639 unique particles!
#
# 9490.208737781786
# 9066
# .
# saved a mean for index 47 with 1709 unique particles!
#
# 9516.503431064486
# 9103
# .
# saved a mean for index 48 with 1805 unique particles!
#
# 9503.559402244551
# 9113
# .
# saved a mean for index 49 with 1863 unique particles!
#
# 9451.407805220304
# 9053
# .  [ 50/86,    1.95sec avg,   70.30sec ETA ]
#
# saved a mean for index 50 with 1905 unique particles!
#
# 9483.512886534867
# 9087
# .
# saved a mean for index 51 with 1954 unique particles!
#
# 9523.7659085515
# 9126
# .
# saved a mean for index 52 with 1980 unique particles!
#
# 9386.950824220876
# 9018
# .
# saved a mean for index 53 with 2001 unique particles!
#
# 8948.197809579699
# 8642
# .
# saved a mean for index 54 with 1975 unique particles!
#
# 9103.261900753077
# 8757
# .
# saved a mean for index 55 with 1931 unique particles!
#
# 8764.824632673966
# 8495
# .
# saved a mean for index 56 with 1844 unique particles!
#
# 7841.324073074337
# 7896
# .
# saved a mean for index 57 with 1680 unique particles!
#
# 8046.330138472639
# 7998
# .
# saved a mean for index 58 with 1502 unique particles!
#
# 8079.50124931504
# 8017
# .
# saved a mean for index 59 with 1275 unique particles!
#
# 7909.983598268395
# 7915
# .  [ 60/86,    1.94sec avg,   50.38sec ETA ]
#
# saved a mean for index 60 with 1070 unique particles!
#
# 7091.753257391106
# 7486
# .
# saved a mean for index 61 with 881 unique particles!
#
# 7895.637075022185
# 7923
# .
# saved a mean for index 62 with 732 unique particles!
#
# 8388.597970935392
# 8220
# .
# saved a mean for index 63 with 626 unique particles!
#
# 8933.550040414517
# 8616
# .
# saved a mean for index 64 with 536 unique particles!
#
# 9321.461110533286
# 8949
# .
# saved a mean for index 65 with 507 unique particles!
#
# 9435.896274575842
# 9056
# .
# saved a mean for index 66 with 465 unique particles!
#
# 9588.748352036437
# 9191
# .
# saved a mean for index 67 with 453 unique particles!
#
# 9633.973810530159
# 9225
# .
# saved a mean for index 68 with 446 unique particles!
#
# 9612.119809918046
# 9174
# .
# saved a mean for index 69 with 462 unique particles!
#
# 9699.159080136813
# 9303
# .  [ 70/86,    1.92sec avg,   30.67sec ETA ]
#
# saved a mean for index 70 with 486 unique particles!
#
# 9671.758660320678
# 9264
# .
# saved a mean for index 71 with 555 unique particles!
#
# 9696.887690870135
# 9258
# .
# saved a mean for index 72 with 664 unique particles!
#
# 9654.373518919892
# 9224
# .
# saved a mean for index 73 with 789 unique particles!
#
# 9619.458404816205
# 9208
# .
# saved a mean for index 74 with 936 unique particles!
#
# 9539.673110209666
# 9119
# .
# saved a mean for index 75 with 1189 unique particles!
#
# 9531.569567421271
# 9143
# .
# saved a mean for index 76 with 1569 unique particles!
#
# 9316.746220000943
# 8966
# .
# saved a mean for index 77 with 1836 unique particles!
#
# 9007.569935953092
# 8661
# .
# saved a mean for index 78 with 1962 unique particles!
#
# 9373.703483840682
# 8989
# .
# saved a mean for index 79 with 2029 unique particles!
#
# 9154.7673889944
# 8811
# .  [ 80/86,    1.92sec avg,   11.49sec ETA ]
#
# saved a mean for index 80 with 2049 unique particles!
#
# 9388.987624917774
# 8989
# .
# saved a mean for index 81 with 2046 unique particles!
#
# 9182.077268593473
# 8804
# .
# saved a mean for index 82 with 1967 unique particles!
#
# 9234.883408725509
# 8881
# .
# saved a mean for index 83 with 1864 unique particles!
#
# 9288.415540841477
# 8906
# .
# saved a mean for index 84 with 1773 unique particles!
#
# 9065.240239468696
# 8753
# .
# saved a mean for index 85 with 1654 unique particles!
#
# 9025.492953384179
# 8782
# .
#    1.93sec avg,  166.04sec total

# %%
import visualization

# %%
root = os.path.dirname(os.path.abspath(os.getcwd()))
pickle_file = os.path.join(root,"pyparticles/results/8218897506270013465.100.200/96")
out_file = os.path.join(root,"data/results_movies/mouse13")
from pathlib import Path
Path(out_file).mkdir(parents=True, exist_ok=True)

# %%
visualization.meantrack_sidebyside_movie(pickle_file,out_file)

# %%
import cv2
import os

image_folder = out_file
video_name = os.path.join(root,'data/results_movies/mouse13_video1.avi')

images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 10, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %%
from renderer import load_data
datapath = os.path.join(root, "data/extracted_data/2019-03-20_17-31-38_saline_example_0_000070_results_00.h5")
test_dict = load_data.h5_to_dict(datapath)

# %%
test_dict.keys()
# Out:
# dict_keys(['frames', 'frames_mask', 'metadata', 'scalars', 'timestamps'])
